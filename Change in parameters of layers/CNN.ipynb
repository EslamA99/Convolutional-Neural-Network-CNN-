# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPool2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.utils import to_categorical
from sklearn.model_selection import KFold, StratifiedKFold
import numpy as np

(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()
X_train = X_train.reshape(60000, 28, 28, 1)
X_test = X_test.reshape(10000, 28, 28, 1)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255
y_original = y_train
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
kf = StratifiedKFold(n_splits = 4, shuffle = True)
numOfArc = 4
model = [0] *numOfArc
for j in range(numOfArc):
    model[j] = Sequential()
    model[j].add(Conv2D(j*8+8,kernel_size=5,activation='relu',input_shape=(28,28,1)))
    if j==0:
      model[j].add(MaxPool2D(pool_size=(2,2)))
    elif j==3:
      model[j].add(MaxPool2D(pool_size=(3,3)))
    else:
      model[j].add(MaxPool2D(pool_size=(j*2,j*2)))
    model[j].add(Conv2D(j*16+16,kernel_size=5,activation='relu'))
    if j==1:
      model[j].add(MaxPool2D(pool_size=(3,3)))
    else:
      model[j].add(MaxPool2D(pool_size=(2,2)))
    model[j].add(Flatten())
    model[j].add(Dense(10, activation='softmax'))
    model[j].compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
accuracies=[]
for j in range(numOfArc):
  counter=0
  for t, v in kf.split(X_train, y_original):
    h=model[j].fit(X_train[t], y_train[t], validation_data=(X_train[v], y_train[v]), epochs=4)
  arr=model[j].evaluate(X_test, y_test)
  print('\n\nprediction loss of model',j+1,' = ',arr[0])
  print('prediction accuracy of model',j+1,' = ',arr[1],'\n\n')
  acc=h.history['accuracy'][-1]
  accuracies.append(acc)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# 0
# 1
# 2
# 3
# Epoch 1/4
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.5721 - accuracy: 0.8282 - val_loss: 0.1203 - val_accuracy: 0.9639
# Epoch 2/4
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.0987 - accuracy: 0.9695 - val_loss: 0.0834 - val_accuracy: 0.9737
# Epoch 3/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0710 - accuracy: 0.9789 - val_loss: 0.0679 - val_accuracy: 0.9789
# Epoch 4/4
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.0577 - accuracy: 0.9822 - val_loss: 0.0611 - val_accuracy: 0.9813
# Epoch 1/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0522 - accuracy: 0.9837 - val_loss: 0.0411 - val_accuracy: 0.9867
# Epoch 2/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0435 - accuracy: 0.9864 - val_loss: 0.0415 - val_accuracy: 0.9869
# Epoch 3/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0383 - accuracy: 0.9877 - val_loss: 0.0409 - val_accuracy: 0.9873
# Epoch 4/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0347 - accuracy: 0.9892 - val_loss: 0.0396 - val_accuracy: 0.9882
# Epoch 1/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0329 - accuracy: 0.9897 - val_loss: 0.0362 - val_accuracy: 0.9881
# Epoch 2/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0282 - accuracy: 0.9912 - val_loss: 0.0344 - val_accuracy: 0.9888
# Epoch 3/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0244 - accuracy: 0.9925 - val_loss: 0.0376 - val_accuracy: 0.9882
# Epoch 4/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0231 - accuracy: 0.9927 - val_loss: 0.0447 - val_accuracy: 0.9858
# Epoch 1/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0279 - accuracy: 0.9908 - val_loss: 0.0233 - val_accuracy: 0.9927
# Epoch 2/4
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.0227 - accuracy: 0.9924 - val_loss: 0.0253 - val_accuracy: 0.9917
# Epoch 3/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0198 - accuracy: 0.9933 - val_loss: 0.0310 - val_accuracy: 0.9905
# Epoch 4/4
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.0177 - accuracy: 0.9939 - val_loss: 0.0317 - val_accuracy: 0.9912
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0437 - accuracy: 0.9889
#
#
# prediction loss of model 1  =  0.04370216280221939
# prediction accuracy of model 1  =  0.9889000058174133
#
#
# Epoch 1/4
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.6255 - accuracy: 0.8147 - val_loss: 0.1101 - val_accuracy: 0.9657
# Epoch 2/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.1065 - accuracy: 0.9676 - val_loss: 0.0822 - val_accuracy: 0.9749
# Epoch 3/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0757 - accuracy: 0.9760 - val_loss: 0.0847 - val_accuracy: 0.9739
# Epoch 4/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0645 - accuracy: 0.9793 - val_loss: 0.0574 - val_accuracy: 0.9828
# Epoch 1/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0557 - accuracy: 0.9830 - val_loss: 0.0454 - val_accuracy: 0.9865
# Epoch 2/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0456 - accuracy: 0.9862 - val_loss: 0.0463 - val_accuracy: 0.9859
# Epoch 3/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0394 - accuracy: 0.9878 - val_loss: 0.0543 - val_accuracy: 0.9833
# Epoch 4/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0343 - accuracy: 0.9890 - val_loss: 0.0508 - val_accuracy: 0.9852
# Epoch 1/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0368 - accuracy: 0.9884 - val_loss: 0.0271 - val_accuracy: 0.9917
# Epoch 2/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0306 - accuracy: 0.9905 - val_loss: 0.0303 - val_accuracy: 0.9908
# Epoch 3/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0265 - accuracy: 0.9913 - val_loss: 0.0260 - val_accuracy: 0.9919
# Epoch 4/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0221 - accuracy: 0.9934 - val_loss: 0.0426 - val_accuracy: 0.9863
# Epoch 1/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0274 - accuracy: 0.9907 - val_loss: 0.0175 - val_accuracy: 0.9937
# Epoch 2/4
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.0196 - accuracy: 0.9941 - val_loss: 0.0242 - val_accuracy: 0.9915
# Epoch 3/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0167 - accuracy: 0.9948 - val_loss: 0.0324 - val_accuracy: 0.9886
# Epoch 4/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0152 - accuracy: 0.9954 - val_loss: 0.0285 - val_accuracy: 0.9899
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0455 - accuracy: 0.9882
#
#
# prediction loss of model 2  =  0.04550730064511299
# prediction accuracy of model 2  =  0.9882000088691711
#
#
# Epoch 1/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.5584 - accuracy: 0.8372 - val_loss: 0.0831 - val_accuracy: 0.9738
# Epoch 2/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0795 - accuracy: 0.9753 - val_loss: 0.0815 - val_accuracy: 0.9750
# Epoch 3/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0555 - accuracy: 0.9824 - val_loss: 0.0535 - val_accuracy: 0.9835
# Epoch 4/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0421 - accuracy: 0.9870 - val_loss: 0.0565 - val_accuracy: 0.9823
# Epoch 1/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0389 - accuracy: 0.9881 - val_loss: 0.0340 - val_accuracy: 0.9890
# Epoch 2/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0302 - accuracy: 0.9908 - val_loss: 0.0364 - val_accuracy: 0.9885
# Epoch 3/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0249 - accuracy: 0.9918 - val_loss: 0.0321 - val_accuracy: 0.9901
# Epoch 4/4
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.0204 - accuracy: 0.9933 - val_loss: 0.0339 - val_accuracy: 0.9907
# Epoch 1/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0258 - accuracy: 0.9920 - val_loss: 0.0245 - val_accuracy: 0.9915
# Epoch 2/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0182 - accuracy: 0.9942 - val_loss: 0.0235 - val_accuracy: 0.9920
# Epoch 3/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0153 - accuracy: 0.9951 - val_loss: 0.0230 - val_accuracy: 0.9923
# Epoch 4/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0130 - accuracy: 0.9960 - val_loss: 0.0215 - val_accuracy: 0.9928
# Epoch 1/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0164 - accuracy: 0.9946 - val_loss: 0.0093 - val_accuracy: 0.9969
# Epoch 2/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0118 - accuracy: 0.9960 - val_loss: 0.0110 - val_accuracy: 0.9965
# Epoch 3/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0094 - accuracy: 0.9972 - val_loss: 0.0117 - val_accuracy: 0.9959
# Epoch 4/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0086 - accuracy: 0.9974 - val_loss: 0.0126 - val_accuracy: 0.9953
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0352 - accuracy: 0.9892
#
#
# prediction loss of model 3  =  0.035228319466114044
# prediction accuracy of model 3  =  0.9891999959945679
#
#
# Epoch 1/4
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.4267 - accuracy: 0.8739 - val_loss: 0.0725 - val_accuracy: 0.9762
# Epoch 2/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0614 - accuracy: 0.9804 - val_loss: 0.0530 - val_accuracy: 0.9831
# Epoch 3/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0379 - accuracy: 0.9887 - val_loss: 0.0467 - val_accuracy: 0.9862
# Epoch 4/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0304 - accuracy: 0.9909 - val_loss: 0.0391 - val_accuracy: 0.9887
# Epoch 1/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0301 - accuracy: 0.9910 - val_loss: 0.0233 - val_accuracy: 0.9923
# Epoch 2/4
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.0210 - accuracy: 0.9935 - val_loss: 0.0230 - val_accuracy: 0.9922
# Epoch 3/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0161 - accuracy: 0.9952 - val_loss: 0.0251 - val_accuracy: 0.9917
# Epoch 4/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0126 - accuracy: 0.9958 - val_loss: 0.0236 - val_accuracy: 0.9923
# Epoch 1/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0188 - accuracy: 0.9939 - val_loss: 0.0093 - val_accuracy: 0.9972
# Epoch 2/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0115 - accuracy: 0.9963 - val_loss: 0.0161 - val_accuracy: 0.9941
# Epoch 3/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0092 - accuracy: 0.9970 - val_loss: 0.0138 - val_accuracy: 0.9951
# Epoch 4/4
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.0073 - accuracy: 0.9977 - val_loss: 0.0111 - val_accuracy: 0.9966
# Epoch 1/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0131 - accuracy: 0.9956 - val_loss: 0.0081 - val_accuracy: 0.9975
# Epoch 2/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0067 - accuracy: 0.9978 - val_loss: 0.0197 - val_accuracy: 0.9929
# Epoch 3/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0063 - accuracy: 0.9980 - val_loss: 0.0102 - val_accuracy: 0.9971
# Epoch 4/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.0090 - val_accuracy: 0.9967
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0348 - accuracy: 0.9904
#
#
# prediction loss of model 4  =  0.03484811261296272
# prediction accuracy of model 4  =  0.9904000163078308

# %%
print('Accuracies of models = ',accuracies)
print("Max Accuracy= ",max(accuracies))
index=accuracies.index(max(accuracies))
arr=model[index].evaluate(X_test, y_test)
print('prediction loss of the best model = ',arr[0])
print('prediction accuracy of the best model = ',arr[1])
# Out:
# Accuracies of models =  [0.99391108751297, 0.9954000115394592, 0.997355580329895, 0.9986000061035156]
# Max Accuracy=  0.9986000061035156
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0348 - accuracy: 0.9904
# prediction loss of the best model =  0.03484811261296272
# prediction accuracy of the best model =  0.9904000163078308
