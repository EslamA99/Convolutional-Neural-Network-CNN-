# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPool2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.utils import to_categorical
from sklearn.model_selection import KFold, StratifiedKFold
import numpy as np

(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()
X_train = X_train.reshape(60000, 28, 28, 1)
X_test = X_test.reshape(10000, 28, 28, 1)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255
y_original = y_train
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
kf = StratifiedKFold(n_splits = 4, shuffle = True)
numOfArc = 4
model = [0] *numOfArc
for j in range(numOfArc):
    model[j] = Sequential()
    model[j].add(Conv2D(16,kernel_size=5,padding='same',activation='relu',input_shape=(28,28,1)))
    model[j].add(MaxPool2D(pool_size=(2,2)))
    if j>0:
      model[j].add(Conv2D(32,kernel_size=5,padding='same',activation='relu'))
      model[j].add(MaxPool2D(pool_size=(2,2)))
    if j>1:
      model[j].add(Conv2D(48,kernel_size=5,padding='same',activation='relu'))
      model[j].add(MaxPool2D(pool_size=(2,2)))
    if j>2:
      model[j].add(Conv2D(64,kernel_size=5,padding='same',activation='relu'))
      model[j].add(MaxPool2D(pool_size=(2,2)))

    model[j].add(Flatten())
    model[j].add(Dense(10, activation='softmax'))
    model[j].compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
accuracies=[]
for j in range(numOfArc):
  counter=0
  for t, v in kf.split(X_train, y_original):
    h=model[j].fit(X_train[t], y_train[t], validation_data=(X_train[v], y_train[v]), epochs=4)
  arr=model[j].evaluate(X_test, y_test)
  print('\n\nprediction loss of model',j+1,' in X_text and Y_test = ',arr[0])
  print('prediction accuracy of model',j+1,' in X_text and Y_test = ',arr[1],'\n\n')
  acc=h.history['accuracy'][-1]
  accuracies.append(acc)
# Out:
# 0
# 1
# 2
# 3
# Epoch 1/4
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.4921 - accuracy: 0.8615 - val_loss: 0.1106 - val_accuracy: 0.9696
# Epoch 2/4
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.0996 - accuracy: 0.9702 - val_loss: 0.0808 - val_accuracy: 0.9755
# Epoch 3/4
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.0662 - accuracy: 0.9808 - val_loss: 0.0668 - val_accuracy: 0.9798
# Epoch 4/4
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.0531 - accuracy: 0.9847 - val_loss: 0.0674 - val_accuracy: 0.9798
# Epoch 1/4
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.0503 - accuracy: 0.9848 - val_loss: 0.0511 - val_accuracy: 0.9844
# Epoch 2/4
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.0410 - accuracy: 0.9872 - val_loss: 0.0527 - val_accuracy: 0.9851
# Epoch 3/4
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.0345 - accuracy: 0.9891 - val_loss: 0.0527 - val_accuracy: 0.9844
# Epoch 4/4
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.0296 - accuracy: 0.9909 - val_loss: 0.0530 - val_accuracy: 0.9845
# Epoch 1/4
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.0361 - accuracy: 0.9893 - val_loss: 0.0262 - val_accuracy: 0.9919
# Epoch 2/4
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.0292 - accuracy: 0.9912 - val_loss: 0.0252 - val_accuracy: 0.9923
# Epoch 3/4
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.0245 - accuracy: 0.9927 - val_loss: 0.0268 - val_accuracy: 0.9913
# Epoch 4/4
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.0202 - accuracy: 0.9939 - val_loss: 0.0325 - val_accuracy: 0.9899
# Epoch 1/4
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.0248 - accuracy: 0.9923 - val_loss: 0.0206 - val_accuracy: 0.9933
# Epoch 2/4
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.0185 - accuracy: 0.9944 - val_loss: 0.0179 - val_accuracy: 0.9943
# Epoch 3/4
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.0152 - accuracy: 0.9953 - val_loss: 0.0239 - val_accuracy: 0.9919
# Epoch 4/4
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.0127 - accuracy: 0.9964 - val_loss: 0.0219 - val_accuracy: 0.9925
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0488 - accuracy: 0.9868
#
#
# prediction loss of model 1  =  0.04880768433213234
# prediction accuracy of model 1  =  0.9868000149726868
#
#
# Epoch 1/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.4111 - accuracy: 0.8755 - val_loss: 0.0848 - val_accuracy: 0.9727
# Epoch 2/4
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.0660 - accuracy: 0.9799 - val_loss: 0.0555 - val_accuracy: 0.9829
# Epoch 3/4
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.0410 - accuracy: 0.9869 - val_loss: 0.0455 - val_accuracy: 0.9859
# Epoch 4/4
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.0293 - accuracy: 0.9904 - val_loss: 0.0433 - val_accuracy: 0.9862
# Epoch 1/4
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.0296 - accuracy: 0.9909 - val_loss: 0.0265 - val_accuracy: 0.9919
# Epoch 2/4
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.0220 - accuracy: 0.9930 - val_loss: 0.0285 - val_accuracy: 0.9922
# Epoch 3/4
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.0170 - accuracy: 0.9950 - val_loss: 0.0377 - val_accuracy: 0.9887
# Epoch 4/4
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.0137 - accuracy: 0.9956 - val_loss: 0.0340 - val_accuracy: 0.9915
# Epoch 1/4
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.0205 - accuracy: 0.9937 - val_loss: 0.0114 - val_accuracy: 0.9963
# Epoch 2/4
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.0135 - accuracy: 0.9955 - val_loss: 0.0109 - val_accuracy: 0.9965
# Epoch 3/4
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.0117 - accuracy: 0.9966 - val_loss: 0.0189 - val_accuracy: 0.9939
# Epoch 4/4
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.0093 - accuracy: 0.9971 - val_loss: 0.0158 - val_accuracy: 0.9943
# Epoch 1/4
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.0113 - accuracy: 0.9965 - val_loss: 0.0076 - val_accuracy: 0.9971
# Epoch 2/4
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.0076 - accuracy: 0.9974 - val_loss: 0.0077 - val_accuracy: 0.9976
# Epoch 3/4
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.0080 - accuracy: 0.9974 - val_loss: 0.0109 - val_accuracy: 0.9961
# Epoch 4/4
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.0055 - accuracy: 0.9983 - val_loss: 0.0147 - val_accuracy: 0.9943
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0436 - accuracy: 0.9901
#
#
# prediction loss of model 2  =  0.043605804443359375
# prediction accuracy of model 2  =  0.9901000261306763
#
#
# Epoch 1/4
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.4013 - accuracy: 0.8774 - val_loss: 0.0770 - val_accuracy: 0.9755
# Epoch 2/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0536 - accuracy: 0.9821 - val_loss: 0.0528 - val_accuracy: 0.9841
# Epoch 3/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0335 - accuracy: 0.9897 - val_loss: 0.0484 - val_accuracy: 0.9849
# Epoch 4/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0254 - accuracy: 0.9920 - val_loss: 0.0383 - val_accuracy: 0.9888
# Epoch 1/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0269 - accuracy: 0.9911 - val_loss: 0.0192 - val_accuracy: 0.9938
# Epoch 2/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0187 - accuracy: 0.9939 - val_loss: 0.0268 - val_accuracy: 0.9913
# Epoch 3/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0150 - accuracy: 0.9951 - val_loss: 0.0250 - val_accuracy: 0.9929
# Epoch 4/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0127 - accuracy: 0.9959 - val_loss: 0.0258 - val_accuracy: 0.9919
# Epoch 1/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0165 - accuracy: 0.9952 - val_loss: 0.0085 - val_accuracy: 0.9976
# Epoch 2/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0098 - accuracy: 0.9970 - val_loss: 0.0129 - val_accuracy: 0.9963
# Epoch 3/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0095 - accuracy: 0.9971 - val_loss: 0.0200 - val_accuracy: 0.9946
# Epoch 4/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0079 - accuracy: 0.9976 - val_loss: 0.0241 - val_accuracy: 0.9939
# Epoch 1/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0127 - accuracy: 0.9961 - val_loss: 0.0110 - val_accuracy: 0.9965
# Epoch 2/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0067 - accuracy: 0.9979 - val_loss: 0.0086 - val_accuracy: 0.9968
# Epoch 3/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.0096 - val_accuracy: 0.9971
# Epoch 4/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0064 - accuracy: 0.9979 - val_loss: 0.0079 - val_accuracy: 0.9973
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0359 - accuracy: 0.9918
#
#
# prediction loss of model 3  =  0.035900089889764786
# prediction accuracy of model 3  =  0.9918000102043152
#
#
# Epoch 1/4
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.4097 - accuracy: 0.8677 - val_loss: 0.0651 - val_accuracy: 0.9793
# Epoch 2/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0557 - accuracy: 0.9832 - val_loss: 0.0505 - val_accuracy: 0.9841
# Epoch 3/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0362 - accuracy: 0.9884 - val_loss: 0.0476 - val_accuracy: 0.9855
# Epoch 4/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0271 - accuracy: 0.9909 - val_loss: 0.0346 - val_accuracy: 0.9895
# Epoch 1/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0295 - accuracy: 0.9907 - val_loss: 0.0244 - val_accuracy: 0.9922
# Epoch 2/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0189 - accuracy: 0.9943 - val_loss: 0.0202 - val_accuracy: 0.9942
# Epoch 3/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0162 - accuracy: 0.9948 - val_loss: 0.0264 - val_accuracy: 0.9925
# Epoch 4/4
# 1407/1407 [==============================] - 6s 4ms/step - loss: 0.0145 - accuracy: 0.9952 - val_loss: 0.0354 - val_accuracy: 0.9898
# Epoch 1/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0182 - accuracy: 0.9941 - val_loss: 0.0211 - val_accuracy: 0.9927
# Epoch 2/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0116 - accuracy: 0.9962 - val_loss: 0.0122 - val_accuracy: 0.9960
# Epoch 3/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0108 - accuracy: 0.9968 - val_loss: 0.0245 - val_accuracy: 0.9934
# Epoch 4/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.0250 - val_accuracy: 0.9938
# Epoch 1/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0138 - accuracy: 0.9957 - val_loss: 0.0120 - val_accuracy: 0.9960
# Epoch 2/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0100 - accuracy: 0.9965 - val_loss: 0.0076 - val_accuracy: 0.9976
# Epoch 3/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0073 - accuracy: 0.9978 - val_loss: 0.0135 - val_accuracy: 0.9961
# Epoch 4/4
# 1407/1407 [==============================] - 5s 4ms/step - loss: 0.0083 - accuracy: 0.9973 - val_loss: 0.0162 - val_accuracy: 0.9959
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0451 - accuracy: 0.9906
#
#
# prediction loss of model 4  =  0.04509910196065903
# prediction accuracy of model 4  =  0.9905999898910522

# %%
print('Accuracies of models = ',accuracies)
print("Max Accuracy= ",max(accuracies))
index=accuracies.index(max(accuracies))
arr=model[index].evaluate(X_test, y_test)
print('prediction loss of the best model in X_text and Y_test = ',arr[0])
print('prediction accuracy of the best model in X_text and Y_test = ',arr[1])
# Out:
# Accuracies of models =  [0.996399998664856, 0.9982888698577881, 0.9979110956192017, 0.9973111152648926]
# Max Accuracy=  0.9982888698577881
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0436 - accuracy: 0.9901
# prediction loss of the best model in X_text and Y_test =  0.043605804443359375
# prediction accuracy of the best model in X_text and Y_test =  0.9901000261306763
